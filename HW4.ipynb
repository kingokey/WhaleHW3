# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# ### Whales Return

# %%
whale_returns_csv=(r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_whale_returns.csv")
whale_pd= pd.read_csv(whale_returns_csv, index_col= "Date", parse_dates= True)
df = pd.DataFrame
whale_pd.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# count nulls

whale_pd.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
# Drop nulls
whale_pd.dropna(inplace=True)
whale_pd
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# ...

# %% [markdown]
# ### Algorithmic Daily Returns

# %%
algo_returns_csv= (r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_algo_returns.csv")
algo_pd= pd.read_csv(algo_returns_csv, index_col= "Date", parse_dates= True)
algo_pd.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# count nulls

algo_pd.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
# Drop nulls

algo_pd.dropna(inplace=True)
algo_pd
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ### S&P 500 Returns

# %%
sp500_history_csv= (r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_sp500_history.csv")
sp500_pd= pd.read_csv (sp500_history_csv,index_col="Date", parse_dates=True)
sp500_pd.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Type

sp500_pd.dtypes
# Out:
# Close    object
# dtype: object

# %%
#Fix Data Type
sp500_pd["Close"] = sp500_pd["Close"].str.replace('$', '')
sp500_pd["Close"]= sp500_pd["Close"].astype(float)
sp500_pd.head()
# Out:
# <ipython-input-324-9da3cfc7d8ac>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   sp500_pd["Close"] = sp500_pd["Close"].str.replace('$', '')
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Calculate Returns

sp500_pd["Close"] = sp500_pd["Close"].pct_change()
sp500_pd.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls

sp500_pd.dropna(inplace=True)
sp500_pd
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509
# ...              ...
# 2012-10-05  0.003469
# 2012-10-04  0.000322
# 2012-10-03 -0.007123
# 2012-10-02 -0.003611
# 2012-10-01 -0.000872
#
# [1648 rows x 1 columns]

# %%
# Rename `Close` Column to be specific to this portfolio.

sp500_pd.columns= ["S&P 500"]
sp500_pd.head()
# Out:
#              S&P 500
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %% [markdown]
# ###  Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

all_return= pd.concat([whale_pd, algo_pd, sp500_pd], axis="columns", join="inner")
all_return.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %% [markdown]
# ## Performance Anlysis

# %% [markdown]
# ## Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios

all_return.plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ###  Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# Plot cumulative returns

cumulative_returns = (1+all_return).cumprod() -1
cumulative_returns.plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Risk Analysis

# %% [markdown]
# ## Create a box plot for each portfolio

# %%
 # Box plot to visually show risk

all_return.plot.box(figsize=(20,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

daily_std = all_return.std()
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %% [markdown]
# ## Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
# Determine which portfolios are riskier than the S&P 500

riskier = daily_std[daily_std > daily_std["S&P 500"]]
print(riskier) # Below Portfolios are Riskier because their std is GREATER than SP500
# Out:
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# dtype: float64

# %% [markdown]
# ## Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

annualized_std = daily_std * np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# dtype: float64

# %% [markdown]
# ## Rolling Statistics

# %% [markdown]
# ##  Calculate and plot rolling std for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_return.rolling(window=21).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ##  Calculate and plot the correlation

# %%
## Correlation

import seaborn as sns
correlation = all_return.corr()
sns.heatmap(correlation, vmin=-1, vmax=1,annot=True,)
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
# Calculate variance of S&P 500
# Computing beta
# Plot beta trend

covariance = all_return['BERKSHIRE HATHAWAY INC'].cov(all_return['S&P 500'])
variance = all_return['S&P 500'].var()
beta = covariance / variance
beta
# Out:
# -0.020846489408902394

# %%
rolling_covariance = all_return['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(all_return['S&P 500'])
rolling_variance = all_return['S&P 500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 30-Day Beta of Berkshire Hathaway')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of Berkshire Hathaway'}, xlabel='Date'>

# %%
all_return.ewm(halflife=21).std().plot(figsize=(10,10))
#cumulative_returns = (1 + combined_df).cumprod() - 1
#cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Sharpe Ratios

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
 # Annualized Sharpe Ratios

sharpe_ratios = (all_return.mean() * 252) / (all_return.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ###  Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %%
#Algorithmic outperform both market, because both Algo_1 and Algo_2 combine has more returns than the market

# %% [markdown]
# ### Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
##For this demo solution, we fetch data from three companies listes in the S&P 500 index.
##GOOG - Google, LLCAAPL - Apple Inc.COST - Costco Wholesale Corporation

# %%
# Reading data from 1st stock goog

goog_csv = Path(r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_goog_historical.csv")
goog_df = pd.read_csv(goog_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
goog_df.rename( columns={"Symbol": "GOOG1","NOCP":"GOOG"},inplace = True )
goog_df.drop(columns=['GOOG1'], axis=1, inplace = True)

# %%
# Reading data from 2nd stock AAPL
aapl_csv = Path(r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_aapl_historical.csv")
aapl_df = pd.read_csv(aapl_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
aapl_df.rename( columns={"Symbol": "AAPL1","NOCP":"AAPL"},inplace = True )
aapl_df.drop(columns=['AAPL1'], axis=1, inplace= True)

# %%
# Reading data from 3rd stock

cost_csv = Path(r"C:\Users\okech\OneDrive\Desktop\Week4_Pandas_Week4_Pandas_HW_Starter_Code_Resources_cost_historical.csv")
cost_df = pd.read_csv(cost_csv, index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost_df.rename( columns={"Symbol": "COST1","NOCP":"COST"},inplace = True )
cost_df.drop(columns=['COST1'], axis=1,inplace = True)

# %%
# Combine all stocks in a single DataFrame

combined_stock = pd.concat([goog_df,aapl_df,cost_df], axis='columns', join='inner')
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2019-05-09  1162.38  200.72  243.47
# 2019-05-08  1166.27  202.90  241.34
# 2019-05-07  1174.10  202.86  240.18
# 2019-05-06  1189.39  208.48  244.23
# 2019-05-03  1185.40  211.75  244.62

# %%
# Reset Date index

combined_stock.sort_index(inplace=True)
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %%
# Calculate daily returns
# Drop NAs
# Display sample data


daily_returns = combined_stock.pct_change()
daily_returns.head()
# Out:
#                 GOOG      AAPL      COST
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14  0.001766 -0.002333  0.000613
# 2018-05-15 -0.019060 -0.009088 -0.002042
# 2018-05-16  0.002354  0.009333  0.016523
# 2018-05-17 -0.002940 -0.006324  0.004479

# %%
#drop nulls
combined_stock.dropna(inplace=True)
combined_stock.head()
# Out:
#                GOOG    AAPL    COST
# Trade DATE
# 2018-05-11  1098.26  188.59  195.76
# 2018-05-14  1100.20  188.15  195.88
# 2018-05-15  1079.23  186.44  195.48
# 2018-05-16  1081.77  188.18  198.71
# 2018-05-17  1078.59  186.99  199.60

# %% [markdown]
# ### Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
# Display sample data

weights = [1/3, 1/3, 1/3]
portfolio_returns = daily_returns.dot(weights)

custom = pd.DataFrame(portfolio_returns)
custom.head()
# Out:
#                    0
# Trade DATE
# 2018-05-11       NaN
# 2018-05-14  0.000015
# 2018-05-15 -0.010064
# 2018-05-16  0.009403
# 2018-05-17 -0.001595

# %% [markdown]
# ### Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
# Only compare dates where return data exists for all the stocks (drop NaNs)

all_return_stock = pd.concat([portfolio_returns, all_return], axis='columns', join='inner')
all_return_stock.rename(columns= {0: "Custom"},inplace = True )
all_return_stock.dropna(inplace=True)
all_return_stock.sort_index()
all_return_stock.head()
# Out:
#               Custom  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14  0.000015                   0.000000            0.000000
# 2018-05-15 -0.010064                  -0.000726           -0.001409
# 2018-05-16  0.009403                   0.008637            0.006244
# 2018-05-17 -0.001595                  -0.001955            0.002524
# 2018-05-18 -0.006061                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500
# 2018-05-14  0.001635  0.006889
# 2018-05-15 -0.001139 -0.004044
# ...

# %% [markdown]
# ### Re-run the risk analysis with your portfolio to see how it compares to the others

# %%
# Calculate the annualized `std`

all_return_stock.std()
annualized_variance = (all_return_stock.var()*252)
annualized_std = np.sqrt(annualized_variance)
annualized_std
# Out:
# Custom                         0.211627
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P 500                        0.152469
# dtype: float64

# %% [markdown]
# ###  Calculate and plot rolling std with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation

all_return_stock.rolling(window=21).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Calculate and plot the correlation

# %%
# Calculate and plot the correlation

correlation = all_return_stock.corr()
correlation
# Out:
#                                Custom  SOROS FUND MANAGEMENT LLC  \
# Custom                       1.000000                   0.732548
# SOROS FUND MANAGEMENT LLC    0.732548                   1.000000
# PAULSON & CO.INC.            0.643828                   0.791802
# TIGER GLOBAL MANAGEMENT LLC  0.390961                   0.477844
# BERKSHIRE HATHAWAY INC       0.800558                   0.816197
# Algo 1                       0.260331                   0.336909
# Algo 2                       0.739020                   0.862583
# S&P 500                      0.005603                  -0.028256
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Custom                                 0.643828                     0.390961
# SOROS FUND MANAGEMENT LLC              0.791802                     0.477844
# PAULSON & CO.INC.                      1.000000                     0.484869
# ...

# %%
sns.heatmap(correlation, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot the correlation
# Calculate and plot Beta

rolling_variance = all_return_stock['BERKSHIRE HATHAWAY INC'].rolling(window=60).var()
rolling_covariance = all_return_stock['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(all_return_stock['S&P 500'])
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta BERKSHIRE HATHAWAY INC')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta BERKSHIRE HATHAWAY INC'}>

# %% [markdown]
# ###  Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

sharpe_ratios_all = (all_return_stock.mean() * 252) / ((all_return_stock).std() * np.sqrt(252))
sharpe_ratios_all
# Out:
# Custom                         0.876152
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P 500                       -0.427676
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

sharpe_ratios_all.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
#Algo_1 is the most performing
#Tiger is the least
